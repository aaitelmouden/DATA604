# %% [markdown]
# # Modeling and Simulation in Python
#
# Chapter 6
#
# Copyright 2017 Allen Downey
#
# License: [Creative Commons Attribution 4.0 International](https://creativecommons.org/licenses/by/4.0)

# %%
# Configure Jupyter so figures appear in the notebook
# %matplotlib inline

# Configure Jupyter to display the assigned value after an assignment
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'

# import functions from the modsim.py module
from modsim import *

from pandas import read_html

# %% [markdown]
# ### Code from the previous chapter

# %%
filename = 'https://en.wikipedia.org/wiki/Estimates_of_historical_world_population'
tables = read_html(filename, header=0, index_col=0, decimal='M')
table2 = tables[2]
table2.columns = ['census', 'prb', 'un', 'maddison', 
                  'hyde', 'tanton', 'biraben', 'mj', 
                  'thomlinson', 'durand', 'clark']

# %%
un = table2.un / 1e9
un.head()
# Out:
# Year
# 1950    2.525149
# 1951    2.572851
# 1952    2.619292
# 1953    2.665865
# 1954    2.713172
# Name: un, dtype: float64

# %%
census = table2.census / 1e9
census.head()
# Out:
# Year
# 1950    2.557629
# 1951    2.594940
# 1952    2.636772
# 1953    2.682053
# 1954    2.730228
# Name: census, dtype: float64

# %%
t_0 = get_first_label(census)
t_end = get_last_label(census)
elapsed_time = t_end - t_0

p_0 = get_first_value(census)
p_end = get_last_value(census)
total_growth = p_end - p_0

annual_growth = total_growth / elapsed_time
# Out:
# 0.07224800083333333

# %% [markdown]
# ### System objects

# %% [markdown]
# We can rewrite the code from the previous chapter using system objects.

# %%
system = System(t_0=t_0, 
                t_end=t_end,
                p_0=p_0,
                annual_growth=annual_growth)
# Out:
# t_0              1950.000000
# t_end            2016.000000
# p_0                 2.557629
# annual_growth       0.072248
# dtype: float64

# %% [markdown]
# And we can encapsulate the code that runs the model in a function.

# %%
def run_simulation1(system):
    """Runs the constant growth model.
    
    system: System object
    
    returns: TimeSeries
    """
    results = TimeSeries()
    results[system.t_0] = system.p_0
    
    for t in linrange(system.t_0, system.t_end):
        results[t+1] = results[t] + system.annual_growth
    
    return results

# %% [markdown]
# We can also encapsulate the code that plots the results.

# %%
def plot_results(census, un, timeseries, title):
    """Plot the estimates and the model.
    
    census: TimeSeries of population estimates
    un: TimeSeries of population estimates
    timeseries: TimeSeries of simulation results
    title: string
    """
    plot(census, ':', label='US Census')
    plot(un, '--', label='UN DESA')
    plot(timeseries, color='gray', label='model')
    
    decorate(xlabel='Year', 
             ylabel='World population (billion)',
             title=title)

# %% [markdown]
# Here's how we run it.

# %%
results = run_simulation1(system)
plot_results(census, un, results, 'Constant growth model')

# %% [markdown]
# ## Proportional growth

# %% [markdown]
# Here's a more realistic model where the number of births and deaths is proportional to the current population.

# %%
def run_simulation2(system):
    """Run a model with proportional birth and death.
    
    system: System object
    
    returns: TimeSeries
    """
    results = TimeSeries()
    results[system.t_0] = system.p_0
    
    for t in linrange(system.t_0, system.t_end):
        births = system.birth_rate * results[t]
        deaths = system.death_rate * results[t]
        results[t+1] = results[t] + births - deaths
        
    return results

# %% [markdown]
# I picked a death rate that seemed reasonable and then adjusted the birth rate to fit the data.

# %%
system.death_rate = 0.01
system.birth_rate = 0.027

# %% [markdown]
# Here's what it looks like.

# %%
results = run_simulation2(system)
plot_results(census, un, results, 'Proportional model')
savefig('figs/chap06-fig01.pdf')
# Out:
# Saving figure to file figs/chap06-fig01.pdf

# %% [markdown]
# The model fits the data pretty well for the first 20 years, but not so well after that.

# %% [markdown]
# ### Factoring out the update function

# %% [markdown]
# `run_simulation1` and `run_simulation2` are nearly identical except the body of the loop.  So we can factor that part out into a function.

# %%
def update_func1(pop, t, system):
    """Compute the population next year.
    
    pop: current population
    t: current year
    system: system object containing parameters of the model
    
    returns: population next year
    """
    ############################# Exercise 1 solution ############################
    
    print ("The current population: ", pop)
    print ("The current Year:", t)
    
    #############################################################################
    births = system.birth_rate * pop
    deaths = system.death_rate * pop
    return pop + births - deaths

# %% [markdown]
# The name `update_func` refers to a function object.

# %%
update_func1
# Out:
# <function __main__.update_func1(pop, t, system)>

# %% [markdown]
# Which we can confirm by checking its type.

# %%
type(update_func1)
# Out:
# function

# %% [markdown]
# `run_simulation` takes the update function as a parameter and calls it just like any other function.

# %%
def run_simulation(system, update_func):
    """Simulate the system using any update function.
    
    system: System object
    update_func: function that computes the population next year
    
    returns: TimeSeries
    """
    results = TimeSeries()
    results[system.t_0] = system.p_0
    
    for t in linrange(system.t_0, system.t_end):
        results[t+1] = update_func(results[t], t, system)
        
    return results

# %% [markdown]
# Here's how we use it.

# %%
t_0 = get_first_label(census)
t_end = get_last_label(census)
p_0 = census[t_0]

system = System(t_0=t_0, 
                t_end=t_end,
                p_0=p_0,
                birth_rate=0.027,
                death_rate=0.01)
# Out:
# t_0           1950.000000
# t_end         2016.000000
# p_0              2.557629
# birth_rate       0.027000
# death_rate       0.010000
# dtype: float64

# %%
results = run_simulation(system, update_func1)
plot_results(census, un, results, 'Proportional model, factored')
# Out:
# The current population:  2.557628654
# The current Year: 1950
# The current population:  2.601108341118
# The current Year: 1951
# The current population:  2.645327182917006
# The current Year: 1952
# The current population:  2.6902977450265952
# The current Year: 1953
# The current population:  2.7360328066920476
# The current Year: 1954
# The current population:  2.7825453644058125
# The current Year: 1955
# The current population:  2.829848635600711
# The current Year: 1956
# The current population:  2.8779560624059233
# The current Year: 1957
# The current population:  2.926881315466824
# The current Year: 1958
# The current population:  2.9766382978297603
# The current Year: 1959
# The current population:  3.0272411488928666
# The current Year: 1960
# The current population:  3.078704248424045
# The current Year: 1961
# The current population:  3.131042220647254
# The current Year: 1962
# The current population:  3.184269938398258
# The current Year: 1963
# The current population:  3.2384025273510284
# The current Year: 1964
# The current population:  3.293455370315996
# The current Year: 1965
# The current population:  3.349444111611368
# The current Year: 1966
# The current population:  3.406384661508761
# The current Year: 1967
# The current population:  3.46429320075441
# The current Year: 1968
# The current population:  3.523186185167235
# The current Year: 1969
# The current population:  3.583080350315078
# The current Year: 1970
# The current population:  3.6439927162704344
# The current Year: 1971
# The current population:  3.7059405924470314
# The current Year: 1972
# The current population:  3.768941582518631
# The current Year: 1973
# The current population:  3.833013589421448
# The current Year: 1974
# The current population:  3.8981748204416125
# The current Year: 1975
# The current population:  3.9644437923891203
# The current Year: 1976
# The current population:  4.031839336859735
# The current Year: 1977
# The current population:  4.100380605586351
# The current Year: 1978
# The current population:  4.170087075881319
# The current Year: 1979
# The current population:  4.240978556171301
# The current Year: 1980
# The current population:  4.313075191626214
# The current Year: 1981
# The current population:  4.3863974698838595
# The current Year: 1982
# The current population:  4.460966226871885
# The current Year: 1983
# The current population:  4.536802652728707
# The current Year: 1984
# The current population:  4.613928297825096
# The current Year: 1985
# The current population:  4.692365078888122
# The current Year: 1986
# The current population:  4.77213528522922
# The current Year: 1987
# The current population:  4.8532615850781164
# The current Year: 1988
# The current population:  4.935767032024445
# The current Year: 1989
# The current population:  5.0196750715688605
# The current Year: 1990
# The current population:  5.1050095477855315
# The current Year: 1991
# The current population:  5.191794710097886
# The current Year: 1992
# The current population:  5.28005522016955
# The current Year: 1993
# The current population:  5.369816158912433
# The current Year: 1994
# The current population:  5.461103033613944
# The current Year: 1995
# The current population:  5.553941785185382
# The current Year: 1996
# The current population:  5.648358795533533
# The current Year: 1997
# The current population:  5.744380895057604
# The current Year: 1998
# The current population:  5.8420353702735826
# The current Year: 1999
# The current population:  5.941349971568234
# The current Year: 2000
# The current population:  6.042352921084894
# The current Year: 2001
# The current population:  6.145072920743337
# The current Year: 2002
# The current population:  6.249539160395973
# The current Year: 2003
# The current population:  6.355781326122704
# The current Year: 2004
# The current population:  6.46382960866679
# The current Year: 2005
# The current population:  6.573714712014126
# The current Year: 2006
# The current population:  6.685467862118366
# The current Year: 2007
# The current population:  6.799120815774378
# The current Year: 2008
# The current population:  6.9147058696425425
# The current Year: 2009
# The current population:  7.032255869426465
# The current Year: 2010
# The current population:  7.151804219206714
# The current Year: 2011
# The current population:  7.273384890933229
# The current Year: 2012
# The current population:  7.397032434079093
# The current Year: 2013
# The current population:  7.522781985458438
# The current Year: 2014
# The current population:  7.650669279211232
# The current Year: 2015

# %% [markdown]
# Remember not to put parentheses after `update_func1`.  What happens if you try?

# %% [markdown]
# **Exercise:** When you run `run_simulation`, it runs `update_func1` once for each year between `t_0` and `t_end`.  To see that for yourself, add a print statement at the beginning of `update_func1` that prints the values of `t` and `pop`, then run `run_simulation` again.

# %% [markdown]
# ### Combining birth and death

# %% [markdown]
# Since births and deaths get added up, we don't have to compute them separately.  We can combine the birth and death rates into a single net growth rate.

# %%
def update_func2(pop, t, system):
    """Compute the population next year.
    
    pop: current population
    t: current year
    system: system object containing parameters of the model
    
    returns: population next year
    """
    net_growth = system.alpha  * pop
    return pop + net_growth

# %% [markdown]
# Here's how it works:

# %%
system.alpha = system.birth_rate - system.death_rate

results = run_simulation(system, update_func2)
plot_results(census, un, results, 'Proportional model, combined birth and death')

# %% [markdown]
# ### Exercises
#
# **Exercise:** Maybe the reason the proportional model doesn't work very well is that the growth rate, `alpha`, is changing over time.  So let's try a model with different growth rates before and after 1980 (as an arbitrary choice).
#
# Write an update function that takes `pop`, `t`, and `system` as parameters.  The system object, `system`, should contain two parameters: the growth rate before 1980, `alpha1`, and the growth rate after 1980, `alpha2`.  It should use `t` to determine which growth rate to use.  Note: Don't forget the `return` statement.
#
# Test your function by calling it directly, then pass it to `run_simulation`.  Plot the results.  Adjust the parameters `alpha1` and `alpha2` to fit the data as well as you can.

# %%
# Solution

def update_func3(pop, t, system):
    """Compute the population next year.
    
    pop: current population
    t: current year
    system: system object containing parameters of the model
    
    returns: population next year
    """
    if t < 1980: 
        net_growth = system.alpha1 * pop # The net growth before 1980
    else:
        net_growth = system.alpha2 * pop # The net growth after 1980
    return pop + net_growth

# %%
# Solution

system = System(t_0=t_0, 
                t_end=t_end,
                p_0=p_0,
                alpha1 = 0.0195,
                alpha2 = 0.014)

results = run_simulation(system, update_func3)
plot_results(census, un, results, 'Proportional model, parameter changes over time')
